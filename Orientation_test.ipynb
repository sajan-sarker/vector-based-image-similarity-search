# %%
import os
from pathlib import Path
os.chdir(Path().parent)  # Change working directory to the project root
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: d:\Programming\vector-based-image-similarity-search

# %%
import cv2
import random
import matplotlib.pyplot as plt
import numpy as np

from src.config import *
from src.search_face import search
from src.index_faces import vector_id_for, index_directory
from src.face_embedding import generate_face_embedding, _get_app, _normalize
from src.orientation_detection import detect_and_fix_orientation

# %%
sample = "data/query_images/000016_oriented.jpg"
image = cv2.imread(sample)
image
# Out:
# array([[[35, 33, 32],
#         [35, 33, 32],
#         [38, 34, 33],
#         ...,
#         [ 0, 14, 43],
#         [ 0, 14, 43],
#         [ 0, 14, 43]],
#
#        [[35, 33, 32],
#         [35, 33, 32],
#         [38, 34, 33],
#         ...,
#         [ 0, 14, 43],
#         [ 0, 14, 43],
#         [ 0, 14, 43]],
#
#        [[43, 41, 40],
#         [43, 41, 40],
#         [50, 46, 45],
#         ...,
#         [ 3, 17, 45],
#         [ 3, 17, 45],
#         [ 3, 17, 45]],
#
#        ...,
#
#        [[30, 35, 34],
#         [30, 35, 34],
#         [30, 35, 34],
#         ...,
#         [19, 24, 23],
#         [19, 24, 23],
#         [19, 24, 23]],
#
#        [[30, 35, 34],
#         [30, 35, 34],
#         [30, 35, 34],
#         ...,
#         [19, 24, 23],
#         [19, 24, 23],
#         [19, 24, 23]],
#
#        [[30, 35, 34],
#         [30, 35, 34],
#         [30, 35, 34],
#         ...,
#         [19, 24, 23],
#         [19, 24, 23],
#         [19, 24, 23]]], shape=(218, 178, 3), dtype=uint8)

# %%
# display the raw image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
fixed, det_angle = detect_and_fix_orientation(sample)

# %%
plt.imshow(cv2.cvtColor(fixed, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
det_angle
# Out:
# 180
